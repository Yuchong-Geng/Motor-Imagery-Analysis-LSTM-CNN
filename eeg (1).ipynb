# %%
import keras
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Read in data in .mat format

# %%
import scipy.io as sio
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load All subjects' data

# %%
s01 = sio.loadmat('drive/My Drive/eeg dataset/s01.mat')
s12 = sio.loadmat('drive/My Drive/eeg dataset/s12.mat')
s13 = sio.loadmat('drive/My Drive/eeg dataset/s13.mat')
s03 = sio.loadmat('drive/My Drive/eeg dataset/s03.mat')
s14 = sio.loadmat('drive/My Drive/eeg dataset/s14.mat')
s32 = sio.loadmat('drive/My Drive/eeg dataset/s32.mat')
s40 = sio.loadmat('drive/My Drive/eeg dataset/s40.mat')
s41 = sio.loadmat('drive/My Drive/eeg dataset/s41.mat')
s43 = sio.loadmat('drive/My Drive/eeg dataset/s43.mat')
s49 = sio.loadmat('drive/My Drive/eeg dataset/s49.mat')
s47 = sio.loadmat('drive/My Drive/eeg dataset/s47.mat')
#3/14:
s29 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s29.mat')
s30 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s30.mat')
s31 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s31.mat')
s33 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s33.mat')
# s34 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s34.mat') bad subject
s35 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s35.mat')
s36 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s36.mat')
s37 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s37.mat')
s38 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s38.mat')
s39 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s39.mat')
s42 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s42.mat')
s44 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s44.mat')
s45 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s45.mat')
s46 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s46.mat')
s48 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s48.mat')
s50 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s50.mat')
s51 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s51.mat')
s52 = sio.loadmat('/content/drive/My Drive/eeg dataset/3:14/s52.mat')
# s29 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s02.mat') bad subject
s01.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'eeg'])

# %%
dataset = []
dataset.append(s01)
dataset.append(s12)
dataset.append(s13)
dataset.append(s03)
dataset.append(s14)
dataset.append(s32)
dataset.append(s40)
dataset.append(s41)
dataset.append(s43)
dataset.append(s49)
dataset.append(s47)
dataset.append(s29)
dataset.append(s30)
dataset.append(s31)
dataset.append(s33)
dataset.append(s35)
dataset.append(s36)
dataset.append(s37)
dataset.append(s38)
dataset.append(s39)
dataset.append(s42)
dataset.append(s44)
dataset.append(s45)
dataset.append(s46)
dataset.append(s48)
dataset.append(s50)
dataset.append(s51)
dataset.append(s52)

# %%
#3/09:
s02 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s02.mat')
s04 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s04.mat')
s05 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s05.mat')
s06 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s06.mat')
s07 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s07.mat')
s08 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s08.mat')
s09 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s09.mat')
s10 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s10.mat')
s11 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s11.mat')
s15 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s15.mat')
s16 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s16.mat')
s17 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s17.mat')
s18 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s18.mat')
s19 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s19.mat')
s20 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s20.mat')
s21 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s21.mat')
s22 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s22.mat')
s23 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s23.mat')
s24 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s24.mat')
s25 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s25.mat')
s26 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s26.mat')
s27 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s27.mat')
s28 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s28.mat')

# %%
dataset = []
dataset.append(s02)
dataset.append(s04)
dataset.append(s05)
dataset.append(s06)
dataset.append(s07)
dataset.append(s08)
dataset.append(s09)
dataset.append(s10)
dataset.append(s11)
dataset.append(s15)
dataset.append(s16)
dataset.append(s17)
dataset.append(s18)
dataset.append(s19)
dataset.append(s20)
dataset.append(s21)
dataset.append(s22)
dataset.append(s23)
dataset.append(s24)
dataset.append(s25)
dataset.append(s26)
dataset.append(s27)
dataset.append(s28)

# %% [markdown]
# ### Data Processing Function:

# %%
class get_data():

    def __init__(self, mat_input):
        self.mat_input = mat_input

    def get_movement(self):
        movement_left = []
        movement_right = []
        movement_event = []
        sliced_left = []
        sliced_right = []
        index = []
        movement_event = self.mat_input['eeg']['movement_event'][0][0][0]
        # get raw dataset
        for i in range(len(self.mat_input['eeg']['movement_left'][0][0])-4):
            movement_left.append(self.mat_input['eeg']['movement_left'][0][0][i])
            movement_right.append(self.mat_input['eeg']['movement_right'][0][0][i])
        #get onset (starting pt) of movement_event:
        for q in range(len(movement_event)):
            if movement_event[q] == 1:
                  index.append(q)
        #slice movement_left and right to only keep actice region:
        for x in range(len(index)):
            temp_left = []
            temp_right = []
            for j in range(len(movement_left)):
                start_index = index[x]
                end_index = start_index + 1536 #three seconds for a period
                temp_left.append(movement_left[j][start_index:end_index])
                temp_right.append(movement_right[j][start_index:end_index])  
            sliced_left.append(temp_left)
            sliced_right.append(temp_right)
        return sliced_left, sliced_right, index, movement_left, movement_right

    def get_img(self):
        img_left = []
        img_right = []
        img_event = []
        sliced_left = []
        sliced_right = []
        index = []
        img_event = self.mat_input['eeg']['imagery_event'][0][0][0]
        # get raw dataset
        for i in range(len(self.mat_input['eeg']['imagery_left'][0][0])-4):
            img_left.append(self.mat_input['eeg']['imagery_left'][0][0][i])
            img_right.append(self.mat_input['eeg']['imagery_right'][0][0][i])
        #get onset (starting pt) of movement_event:
        for q in range(len(img_event)):
            if img_event[q] == 1:
                  index.append(q)
        #slice movement_left and right to only keep actice region:
        for x in range(len(index)):
            img_temp_left = []
            img_temp_right = []
            for j in range(len(img_left)):
                start_index = index[x]
                end_index = start_index + 1536 #three seconds for a period
                img_temp_left.append(img_left[j][start_index:end_index])
                img_temp_right.append(img_right[j][start_index:end_index])  
            sliced_left.append(img_temp_left)
            sliced_right.append(img_temp_right)
        return sliced_left, sliced_right, index, img_left, img_right

# %% [markdown]
# ### Load the data (choose one to run)

# %% [markdown]
# #### One Subject

# %%
import numpy as np
s02 = sio.loadmat('/content/drive/My Drive/eeg dataset/03:09/s02.mat')
data1 = get_data(s02)
left1 = []
right1 = []
event1 = []
left, right, event, img_left, img_right = data1.get_img()

# %% [markdown]
# #### Three Subject

# %%
import numpy as np
data1 = get_data(s01)
data2 = get_data(s12)
data3 = get_data(s13)
left1 = []
right1 = []
event1 = []
left1, right1, event1, img_left1, img_right1 = data1.get_img()
left2 = []
right2 = []
event2 = []
left2, right2, event2, img_left2, img_right2 = data2.get_img()
left3 = []
right3 = []
event3 = []
left3, right3, event3, img_left3, img_right3 = data3.get_img()
left = left1 + left2 + left3
right = right1 + right2 + right3

# %% [markdown]
# #### 11 Female Subjects with selected backgrounds

# %%
import numpy as np
data1 = get_data(s01)
data2 = get_data(s03)
data3 = get_data(s12)
data4 = get_data(s13)
data5 = get_data(s14)
data6 = get_data(s32)
data7 = get_data(s40)
data8 = get_data(s41)
data9 = get_data(s43)
data10 = get_data(s47)
data11 = get_data(s49)
left1 = []
right1 = []
event1 = []
left1, right1, event1, img_left1, img_right1 = data1.get_img()
left2 = []
right2 = []
event2 = []
left2, right2, event2, img_left2, img_right2 = data2.get_img()
left3 = []
right3 = []
event3 = []
left3, right3, event3, img_left3, img_right3 = data3.get_img()
########################
left4 = []
right4 = []
event4 = []
left4, right4, event4, img_left4, img_right4 = data4.get_img()
left5 = []
right5 = []
event5 = []
left5, right5, event5, img_left5, img_right5 = data5.get_img()
left6 = []
right6 = []
event6 = []
left6, right6, event6, img_left6, img_right6 = data6.get_img()
left7 = []
right7 = []
event7 = []
left7, right7, event7, img_left7, img_right7 = data7.get_img()
left8 = []
right8 = []
event8 = []
left8, right8, event8, img_left8, img_right8 = data8.get_img()
left9 = []
right9 = []
event9 = []
left9, right9, event9, img_left9, img_right9 = data9.get_img()
left10 = []
right10 = []
event10 = []
left10, right10, event10, img_left10, img_right10 = data10.get_img()
left11 = []
right11 = []
event11 = []
left11, right11, event11, img_left11, img_right11 = data11.get_img()
left = left1 + left2 + left3 + left4 + left5 + left6 + left7 + left8 + left9 + left10 + left11
right = right1 + right2 + right3 + right4 + right5 + right6 + right7 + right8 + right9 + right10 + right11

# %% [markdown]
# ### Add a Smooth Filter

# %% [markdown]
# #### As shown here, the data fluctrates significantly. So adding a smooth filter will help the network to better understand input data

# %%
import matplotlib.pyplot as plt
plt.plot(left[30][4])
plt.ylabel('one trail of unscaled signal')
plt.show()

# %%
def filter(input_array, window_size):
    1
    total = []
    window = window_size
    new_length = 0
    for i in range(len(input_array)):
        one_trail = []
        for k in range(len(input_array[i])):
            one_channel = []
            for y in range(len(input_array[i][k])):
                if y >= window:
                    sum = input_array[i][k][y-window:y].sum()
                    avg = sum / window
                    one_channel.append(avg)
            one_trail.append(one_channel)
            new_length = len(one_channel)
        total.append(one_trail)
    return total, new_length

# %%
left, new_timesteps = filter(left, 32) 
right, new_timesteps = filter(right, 32)

# %% [markdown]
# #### Now the signal becomes a lot nicer

# %%
plt.plot(left[30][4])
plt.ylabel('one trail of unscaled signal')
plt.show()

# %% [markdown]
# ### Reshape the data so that for one trail, an array with 1536 arrays can be created. Each sub_array contains 64 elements account for 64 channels

# %%
def reshape(input_array):
    output_array = [] #should have 100 elements (arrays) 
    # channel_array = [] #should have 64 elements   
    for i in range(len(input_array)):
        each_trail = []
        before_trans = np.array(input_array[i])
        output_array.append(before_trans.transpose())
    return output_array

# %%
right = reshape(right) #reshape array for the network
left = reshape(left)

# %%
left = normalize(left)
right = normalize(right)

# %%
plt.plot(left[1])
plt.title('left MI Trail # 1 from one subject')
plt.xlabel('Time')
plt.ylabel('Normaized Mag')
# plt.show()
plt.savefig('left MI Trail # 1 from one subject')
plt.plot(left[10])
plt.title('left MI Trail # 10 from one subject')
plt.xlabel('Time')
plt.ylabel('Normaized Mag')
# plt.show()
plt.savefig('left MI Trail # 10 from one subject')
plt.plot(left[50])
plt.title('left MI Trail # 50 from one subject')
plt.xlabel('Time')
plt.ylabel('Normaized Mag')
# plt.show()
plt.savefig('left MI Trail # 50 from one subject')
plt.plot(left[80])
plt.title('left MI Trail # 80 from one subject')
plt.xlabel('Time')
plt.ylabel('Normaized Mag')
# plt.show()
plt.savefig('left MI Trail # 80 from one subject')

# %%
label = []
X = []
for i in range(len(left)):
    label.append([0]) #set left to 1 and right to 0
    X.append(left[i])
for y in range(len(right)):
    label.append([1])
    X.append(right[y])

#shuffle arrays for randomness:
import random 
temp = list(zip(X, label)) 
random.shuffle(temp) 
X, label = zip(*temp)

# %% [markdown]
# #### Transfer into numpy array

# %%
label = np.array(label)
X = np.array(X)

# %%
X[0][0]
# Out:
# array([ -34112.246, -148618.25 , -170967.25 ,  345183.   ,  434364.   ,
#         131647.75 , -308130.5  ,   56138.   ,  257412.   ,   47028.5  ,
#         188759.   ,  130746.25 ,  293533.5  , -183537.75 ,   37799.   ,
#          19021.25 ,  160881.75 ,  162815.   ,  175207.25 ,  103270.5  ,
#         144066.5  ,   41716.   ,   39162.25 , -354975.   ,  104592.   ,
#         319786.25 ,  270846.75 ,   68031.   ,   92097.75 ,   83772.25 ,
#         206827.   ,  242713.5  ,  -67032.5  ,  263954.75 ,  -53658.246,
#        -181040.25 ,  -93459.75 ,  165225.25 ,   72727.75 ,   23627.75 ,
#         -16109.496,  108630.   ,  -60598.496,  -17194.996,  -92445.5  ,
#         306540.5  ,   73620.5  ,   14580.25 ,  103645.   ,  100644.   ,
#          82796.25 , -196804.75 , -148665.   ,   61806.5  ,  934881.75 ,
#         248811.75 ,   39350.25 ,  121832.75 ,  148108.   ,  -21664.496,
#        -147603.   ,   24815.   ,  199294.25 , -128920.   ], dtype=float32)

# %% [markdown]
# #### As shown here, the data looks like flat lines because they have different off-sets, so we need to normalize our date

# %%
from sklearn.preprocessing import StandardScaler
def normalize(input_data):
    output_data = []
    for i in range(len(input_data)):
        scaler = StandardScaler()
        scaler.fit(input_data[i])
        scaled_X = scaler.transform(input_data[i])
        output_data.append(scaled_X)
    return output_data

# %%
import math as math
element_num = len(X)
train_index = element_num * 0.8 #choose 80% for training and 20% for validation
train_index = math.floor(train_index)
scaled_X = normalize(X) #normalize input data
scaled_X = np.array(scaled_X)
train_X = scaled_X[:train_index]
train_label = label[:train_index]
test_X = scaled_X[train_index:]
test_label = label[train_index:]

# %%
plt.plot(scaled_X[8])
plt.ylabel('one trail of scaled signal')
plt.show()

# %% [markdown]
# ### Build the neraul network

# %% [markdown]
# #### K-fold Cross Validation

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D
from keras.layers import Input
import keras
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# define 10-fold cross validation test harness
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []
# code for building an LSTM with 100 neurons and dropout. Runs for 50 epochs
time_steps = 1536
n_features = 64
X = normalize(X) #normalize input data
X = np.array(scaled_X)
for train, test in kfold.split(X, label):

    # val_data = (X[test], label[test])
    model = Sequential()
    model.add(Conv1D(filters=250, #200 get 0.6955
                    kernel_size=75,
                    strides=1,
                    activation='relu',
                    padding='same'))
    model.add(Dropout(0.5))
    model.add(Conv1D(filters=250,
                    kernel_size=75,
                    strides=1,
                    activation='relu',
                    padding='same'))
    model.add(Dropout(0.4))
    model.add(MaxPooling1D(4))
    model.add(Conv1D(75, 75, activation='relu'))
    # model.add(Conv1D(160, 100, activation='relu'))
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    sgd = keras.optimizers.SGD(0.00025, 0.0, False) #0.0001 for combined dataset
    model.compile(loss='binary_crossentropy',
                  # optimizer='adam',
                  optimizer=sgd,
                  metrics=['accuracy'])
    rnn = model.fit(X[train], label[train], batch_size=16, epochs=50, verbose=0)
    scores = model.evaluate(X[test], label[test], verbose=0)
    print('%s: %.2f%%' % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print('%.2f%% (+/- %.2f%%)' % (numpy.mean(cvscores), numpy.std(cvscores)))
# Out:
# acc: 55.00%
# acc: 70.00%
# acc: 75.00%
# acc: 80.00%
# acc: 80.00%
# acc: 50.00%
# acc: 60.00%
# acc: 60.00%
# acc: 55.00%
# acc: 60.00%
# 64.50% (+/- 10.36%)

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2529013815893061368
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 17214268522865637241
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13244057403644666701
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15956161332
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 223097726582349245
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %% [markdown]
# #### LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D
from keras.layers import Input
# code for building an LSTM with 100 neurons and dropout. Runs for 50 epochs
time_steps = new_timesteps
n_features = 64
#write validation data into a tuple:
val_data = (test_X, test_label)
model = Sequential()
# model.add(Conv1D(filters=64,
#                  kernel_size=64,
#                  strides=1,
#                  activation='relu',
#                  padding='same', 
#                  input_shape=(time_steps, n_features)))
model.add(LSTM(150, return_sequences=True, input_shape=(time_steps, n_features)))
model.add(Dropout(0.2))
model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(75, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(20, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
sgd = keras.optimizers.SGD(0.01, 0.0, False)
model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])
rnn = model.fit(train_X, train_label, batch_size=32, epochs=50, validation_data=val_data)
# score = model.evaluate(test_X, test_label)
#Visulize Result
# Plot training & validation accuracy values
plt.plot(rnn.history['acc'])
plt.plot(rnn.history['val_acc'])
plt.title('Model accuracy for 3 combined datasets from different subjects')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Model relu for 3 combined data from different subjects.png')
plt.show()

# Plot training & validation loss values
plt.plot(rnn.history['loss'])
plt.plot(rnn.history['val_loss'])
plt.title('Model loss for 3 combined data from different subjects')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Model loss for 3 combined data from different subjects.png')
plt.show()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %% [markdown]
# #### CNN

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D
from keras.layers import Input
import keras
# time_steps = new_timesteps
time_steps = 1536
n_features = 64
#write validation data into a tuple:
val_data = (test_X, test_label)
model = Sequential()
model.add(Conv1D(filters=250, #200 get 0.6955
                 kernel_size=75,
                 strides=1,
                 activation='relu',
                 padding='same'))
model.add(Dropout(0.6))
model.add(Conv1D(filters=250,
                 kernel_size=75,
                 strides=1,
                 activation='relu',
                 padding='same'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(4))
model.add(Conv1D(75, 75, activation='relu'))
# model.add(Conv1D(160, 100, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
sgd = keras.optimizers.SGD(0.00020, 0.0, False) #0.0001 for combined dataset
model.compile(loss='binary_crossentropy',
              # optimizer='adam',
              optimizer=sgd,
              metrics=['accuracy'])
# model.summary()
rnn = model.fit(train_X, train_label, batch_size=2, epochs=50, validation_data=val_data) #batch size=16 for 11 subjects' data
# print('%s: %.2f%%' % (model.metrics_names[1], scores[1]*100))
# score = model.evaluate(test_X, test_label)
#Visulize Result
# Plot training & validation accuracy values
plt.plot(rnn.history['acc'])
plt.plot(rnn.history['val_acc'])
plt.title('1D-CNN Model accuracy for subject 12')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('1D-CNN Model accuracy for subject 12.png')
plt.show()

# Plot training & validation loss values
plt.plot(rnn.history['loss'])
plt.plot(rnn.history['val_loss'])
plt.title('1D-CNN Model loss for subject 12')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('1D-CNN Model loss for subject 12')
plt.show()
# Out:
# Train on 160 samples, validate on 40 samples
# Epoch 1/50
# 160/160 [==============================] - 5s 29ms/step - loss: 0.7991 - acc: 0.5000 - val_loss: 0.7132 - val_acc: 0.4250
# Epoch 2/50
# 160/160 [==============================] - 2s 11ms/step - loss: 0.7627 - acc: 0.4500 - val_loss: 0.6948 - val_acc: 0.4250
# Epoch 3/50
# 160/160 [==============================] - 2s 11ms/step - loss: 0.7034 - acc: 0.4875 - val_loss: 0.6989 - val_acc: 0.4250
# Epoch 4/50
# 160/160 [==============================] - 2s 11ms/step - loss: 0.7035 - acc: 0.5062 - val_loss: 0.6933 - val_acc: 0.4500
# Epoch 5/50
# 160/160 [==============================] - 2s 11ms/step - loss: 0.7034 - acc: 0.4875 - val_loss: 0.6882 - val_acc: 0.6750
# Epoch 6/50
# 160/160 [==============================] - 2s 11ms/step - loss: 0.6917 - acc: 0.5312 - val_loss: 0.6948 - val_acc: 0.4250
# Epoch 7/50
# ...

# %%
print(rnn.history['val_acc'][49])
# Out:
# 0.75

# %% [markdown]
# ### Visualize the Results

# %%
# Plot training & validation accuracy values
plt.plot(rnn.history['acc'])
plt.plot(rnn.history['val_acc'])
plt.title('Model accuracy for combined data from different subjects')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Model accuracy for combined data from different subjects.png')
plt.show()

# Plot training & validation loss values
plt.plot(rnn.history['loss'])
plt.plot(rnn.history['val_loss'])
plt.title('Model loss for combined data from different subjects')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Model loss for combined data from different subjects.png')
plt.show()

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %% [markdown]
# ### Process all the data:

# %%
import numpy as np
import random 
import math as math
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D
from keras.layers import Input
import keras

val_acc_score2 = []
for s in dataset:
    data1 = get_data(s)
    left1 = []
    right1 = []
    event1 = []
    left, right, event, img_left, img_right = data1.get_img()
    right = reshape(right) #reshape array for the network
    left = reshape(left)
    label = []
    X = []
    for i in range(len(left)):
        label.append([0]) #set left to 1 and right to 0
        X.append(left[i])
    for y in range(len(right)):
        label.append([1])
        X.append(right[y])

    #shuffle arrays for randomness:
    temp = list(zip(X, label)) 
    random.shuffle(temp) 
    X, label = zip(*temp) 
    label = np.array(label)
    X = np.array(X) 
    element_num = len(X)
    train_index = element_num * 0.8 #choose 80% for training and 20% for validation
    train_index = math.floor(train_index)
    scaled_X = normalize(X) #normalize input data
    scaled_X = np.array(scaled_X)
    train_X = scaled_X[:train_index]
    train_label = label[:train_index]
    test_X = scaled_X[train_index:]
    test_label = label[train_index:]
    time_steps = 1536
    n_features = 64
    #write validation data into a tuple:
    val_data = (test_X, test_label)
    model = Sequential()
    model.add(Conv1D(filters=250, #200 get 0.6955
                    kernel_size=75,
                    strides=1,
                    activation='relu',
                    padding='same'))
    model.add(Dropout(0.6))
    model.add(Conv1D(filters=250,
                    kernel_size=75,
                    strides=1,
                    activation='relu',
                    padding='same'))
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(4))
    model.add(Conv1D(75, 75, activation='relu'))
    # model.add(Conv1D(160, 100, activation='relu'))
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    sgd = keras.optimizers.SGD(0.00020, 0.0, False) #0.0001 for combined dataset
    model.compile(loss='binary_crossentropy',
                  # optimizer='adam',
                  optimizer=sgd,
                  metrics=['accuracy'])
    # model.summary()
    rnn = model.fit(train_X, train_label, batch_size=2, epochs=50, validation_data=val_data, verbose=0) #batch size=16 for 11 subjects' data
    print(rnn.history['val_acc'][49])
    val_acc_score2.append(rnn.history['val_acc'][49])
# Out:
# 0.475
# 0.675
# 1.0
# 0.775
# 0.5416666666666666
# 0.475
# 0.6041666666666666
# 0.55
# 0.45
# 0.55
# 0.425
# 0.475
# 0.625
# 0.575
# 0.675
# 0.6
# 0.65
# 0.775
# 0.575
# 0.475
# 0.95
# 0.375
# 0.875

# %%
import numpy
print('%.2f%% (+/- %.2f%%)' % (numpy.mean(val_acc_score2) * 100, numpy.std(val_acc_score2) * 100))
# Out:
# 61.50% (+/- 16.21%)

# %%
val_acc_score
# Out:
# [0.625,
#  0.725,
#  1.0,
#  0.825,
#  0.575,
#  0.425,
#  0.65,
#  0.425,
#  0.975,
#  0.95,
#  0.875,
#  0.425,
#  0.725,
#  0.375,
#  0.6,
#  0.55,
#  0.4,
#  0.75,
#  0.525,
#  0.675,
#  0.475,
#  1.0,
#  0.525,
#  0.6875,
#  0.6,
#  1.0,
#  0.5,
#  0.6]

# %%
val_acc_score = [0.625,
 0.725,
 1.0,
 0.825,
 0.575,
 0.425,
 0.65,
 0.425,
 0.975,
 0.95,
 0.875,
 0.425,
 0.725,
 0.375,
 0.6,
 0.55,
 0.4,
 0.75,
 0.525,
 0.675,
 0.475,
 1.0,
 0.525,
 0.6875,
 0.6,
 1.0,
 0.5,
 0.6]

# %%
for i in val_acc_score2:
    val_acc_score.append(i)

# %%
import numpy
print('%.2f%% (+/- %.2f%%)' % (numpy.mean(val_acc_score) * 100, numpy.std(val_acc_score) * 100))
# Out:
# 66.25% (+/- 17.87%)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
y_pos = np.arange(len(val_acc_score))
 
# Create bars
plt.bar(y_pos, val_acc_score)
plt.title('classification accuracies over all subjects')
plt.ylabel('validation accuracy')
 
# Show graphic
plt.show()
plt.savefig('classification accuracies over all subjects.png')
